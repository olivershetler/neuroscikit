# %%
# To be able to make edits to repo without having to restart notebook
# %load_ext autoreload
# %autoreload 2

# %%
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, mannwhitneyu, wilcoxon, ttest_rel, ttest_ind
import seaborn as sns
from matplotlib.patches import FancyArrowPatch
from matplotlib.colors import ColorConverter

remap_path = os.getcwd()
prototype_path = os.path.abspath(os.path.join(remap_path, os.pardir))
project_path = os.path.abspath(os.path.join(prototype_path, os.pardir))
lab_path = os.path.abspath(os.path.join(project_path, os.pardir))
sys.path.append(project_path)
os.chdir(project_path)
sys.path.append(project_path)
print(project_path)
# Out:
# c:\Users\aaoun\OneDrive - cumc.columbia.edu\Desktop\HussainiLab\neuroscikit

# %%
from scripts.batch_map.LEC_naming import LEC_naming_format, extract_name_lec

# %%
ANT_path = r"C:\Users\aaoun\OneDrive - cumc.columbia.edu\Desktop\HussainiLab\neuroscikit_test_data\LEC_remapping\ANT"
NON_path = r"C:\Users\aaoun\OneDrive - cumc.columbia.edu\Desktop\HussainiLab\neuroscikit_test_data\LEC_remapping\NON"
B6_path = r"C:\Users\aaoun\OneDrive - cumc.columbia.edu\Desktop\HussainiLab\neuroscikit_test_data\LEC_remapping\B6"
dfs = []
for path in [ANT_path, NON_path, B6_path]:
    for animal_dir in os.listdir(path):
        for csv_file in os.listdir(path + r'\\' + animal_dir):
            if csv_file.endswith('.xlsx'):
                file_df = pd.read_excel(path + r'\\' + animal_dir + r'\\' + csv_file)
                # add column for genotype
                if path == ANT_path:
                    file_df['group'] = 'ANT'
                elif path == NON_path:
                    file_df['group'] = 'NON'
                elif path == B6_path:
                    file_df['group'] = 'B6'
                dfs.append(file_df)

df_remapping = pd.concat(dfs, ignore_index=True)
df_remapping.columns
# Out:
# Index(['Unnamed: 0', 'signature', 'depth', 'name', 'date', 'tetrode',
#        'unit_id', 'session_id', 'obj_pos', 'object_location', 'score',
#        'field_id', 'field_count', 'obj_wass_0', 'obj_wass_90', 'obj_wass_180',
#        'obj_wass_270', 'obj_wass_NO', 'obj_q_0', 'obj_q_90', 'obj_q_180',
#        'obj_q_270', 'obj_q_NO', 'obj_vec_0', 'obj_vec_90', 'obj_vec_180',
#        'obj_vec_270', 'obj_vec_NO', 'bin_area', 'total_rate',
#        'field_peak_rate', 'spike_count', 'field_coverage', 'field_area',
#        'field_rate', 'cumulative_coverage', 'cumulative_area',
#        'cumulative_rate', 'arena_size', 'cylinder', 'ratemap_dims', 'spacing',
#        'hexagonal', 'sample_size', 'downsample_factor', 'group'],
#       dtype='object')

# %%
# Match remapping csvs to neurofunc csvss

ANT_path = r"C:\Users\aaoun\OneDrive - cumc.columbia.edu\Desktop\HussainiLab\neuroscikit_test_data\LEC_neurofunc\ANT"
NON_path = r"C:\Users\aaoun\OneDrive - cumc.columbia.edu\Desktop\HussainiLab\neuroscikit_test_data\LEC_neurofunc\NON"
B6_path = r"C:\Users\aaoun\OneDrive - cumc.columbia.edu\Desktop\HussainiLab\neuroscikit_test_data\LEC_neurofunc\B6"
dfs = []
for path in [ANT_path, NON_path, B6_path]:
    for csv_file in os.listdir(path):
        if csv_file.endswith('.xlsx') and '~$' not in csv_file:
            print(csv_file)
            file_df = pd.read_excel(path + r'\\' + csv_file)
            name = csv_file.split('_')[0]
            for i, row in file_df.iterrows():
                signature = row['Session']
                # print(name)
                if name not in signature:
                    signature = name + '_' + signature
                    file_df.at[i, 'Session'] = signature

            # add column for genotype
            if path == ANT_path:
                file_df['group'] = 'ANT'
            elif path == NON_path:
                file_df['group'] = 'NON'
            elif path == B6_path:
                file_df['group'] = 'B6'
            dfs.append(file_df)

df_neurofunc = pd.concat(dfs, ignore_index=True)

from datetime import datetime

NON_set_path = r"C:\Users\aaoun\OneDrive - cumc.columbia.edu\Desktop\HussainiLab\neuroscikit_test_data\LEC_set_files\NON"
ANT_set_path = r"C:\Users\aaoun\OneDrive - cumc.columbia.edu\Desktop\HussainiLab\neuroscikit_test_data\LEC_set_files\ANT"
B6_set_path = r"C:\Users\aaoun\OneDrive - cumc.columbia.edu\Desktop\HussainiLab\neuroscikit_test_data\LEC_set_files\B6"
# insert column for date_time into df_neurofunc
df_neurofunc['date_time'] = pd.NaT
df_neurofunc['ses_ct'] = pd.NaT

for path in [ANT_set_path, NON_set_path, B6_set_path]:
    for animal_dir in os.listdir(path):
        for set_dir in os.listdir(path + r'\\' + animal_dir):
            date_times = {}
            # sigs = []
            for set_file in os.listdir(path + r'\\' + animal_dir + r'\\' + set_dir):
                # print(set_file)
                assert set_file.endswith('.set')
                ses_signature = set_file.split('.')[0]

                # sigs.append(ses_signature)
                # print(set_file)
                with open(path + r'\\' + animal_dir + r'\\' + set_dir + r'\\' + set_file, 'r') as f:
                    for line in f:
                        if 'trial_time' in str(line):
                            # trial_time = line.decode(encoding='UTF-8').split(" ")[1]
                            trial_time = line.split(" ")[1]
                        if 'trial_date' in str(line):
                            trial_date = line.split(" ")[2:]

                    day, month, year = trial_date
                    month = datetime.strptime(str(month), '%b').month
                    hour, minute, second = trial_time.split(':')
                    date_time = datetime(int(year), int(month), int(day), int(hour), int(minute), int(second))

                # assert ses_signature not in date_times.keys(), 'Session signature {} already in dictionary'.format(ses_signature)
                # assert date_time not in date_times.values(), 'Date time {} already in dictionary'.format(date_time) 
                date_times[ses_signature] = date_time

                print(date_time, ses_signature)

            # sort dictionary by date_time
            sigs = list(date_times.keys())
            date_times = list(date_times.values())
            sorted_sigs = [x for _, x in sorted(zip(date_times, sigs))]
            date_times = sorted(date_times)
            # # argsort 
            # sorted_sigs = [x for _, x in sorted(zip(date_times, sigs))]
            print(date_times, sorted_sigs)
            ses_ct = 1
            # print(sorted_sigs)
            for ses in sorted_sigs:

                if len(df_neurofunc[df_neurofunc['Session'] == ses]) == 0:
                    pass
                else:
                    # add date time column
                    df_neurofunc.loc[df_neurofunc['Session'] == ses, 'date_time'] = date_times[ses_ct - 1]
                    df_neurofunc.loc[df_neurofunc['Session'] == ses, 'ses_ct'] = ses_ct
                    ses_ct += 1

print(df_neurofunc.columns)
# Out:
# ANT-119a-6_missing_combined.xlsx
# ANT-119a-6_Unit Matched_combined.xlsx
# ANT-120-4_matched_combined.xlsx
# ANT-133a-4_matched_combined.xlsx
# ANT-135a-7_missing_combined.xlsx
# ANT-135a-7_Unit Matched_combined.xlsx
# ANT-140-4_20180621_summary_sheet_1.xlsx
# ANT-140-4_Unit Matched_combined.xlsx
# NON-73-6_Unit Matched_combined.xlsx
# NON-88-1_missing_combined.xlsx
# NON-88-1_Unit Matched_combined.xlsx
# NON-INT-01_Unit Matched_combined.xlsx
# NON-INT-02_missing_combined.xlsx
# NON-INT-02_Unit Matched_combined.xlsx
# NON-INT-03_20170228_summary_sheet_1.xlsx
# NON-INT-03_Unit Matched_combined.xlsx
# B6-1M_matched_combined.xlsx
# B6-1M_missing_combined.xlsx
# B6-2M_matched_combined.xlsx
# B6-2M_missing_combined.xlsx
# B6-LEC1_,missing_combined.xlsx
# B6-LEC1_matched_combined.xlsx
# B6-LEC2_20160112_summary_sheet_1.xlsx
# B6-LEC2_matched_combined.xlsx
# B6-LEC2_missing_combined.xlsx
# B6-LEC2_more_missing_combined.xlsx
# 2017-06-05 14:51:07 ANT-119a-6_20170605-3050-0
# 2017-06-05 14:28:49 ANT-119a-6_20170605-3050-270
# [datetime.datetime(2016, 4, 21, 10, 52, 17), datetime.datetime(2016, 4, 21, 10, 52, 17), datetime.datetime(2016, 4, 21, 11, 3, 55), datetime.datetime(2016, 4, 21, 11, 17, 15)] ['B6-LEC2_20160421-NO', 'B6-LEC2_20160421-noobject', 'B6-LEC2_20160421-180', 'B6-LEC2_20160421-270']
# 2016-04-22 11:20:47 B6-LEC2_20160422-90
# 2016-04-22 11:04:11 B6-LEC2_20160422-NO
# [datetime.datetime(2016, 4, 22, 11, 4, 11), datetime.datetime(2016, 4, 22, 11, 20, 47)] ['B6-LEC2_20160422-NO', 'B6-LEC2_20160422-90']
# 2016-04-25 13:05:21 B6-LEC2_20160425-0banana
# 2016-04-25 12:43:55 B6-LEC2_20160425-180
# 2016-04-25 12:24:10 B6-LEC2_20160425-NO
# 2016-04-25 12:24:10 B6-LEC2_20160425-noobject
# [datetime.datetime(2016, 4, 25, 12, 24, 10), datetime.datetime(2016, 4, 25, 12, 24, 10), datetime.datetime(2016, 4, 25, 12, 43, 55), datetime.datetime(2016, 4, 25, 13, 5, 21)] ['B6-LEC2_20160425-NO', 'B6-LEC2_20160425-noobject', 'B6-LEC2_20160425-180', 'B6-LEC2_20160425-0banana']
# Index(['Unnamed: 0', 'Session', 'Tetrode', 'Cell ID', 'spike_width',
#        'spike_count', 'firing_rate', 'Avg. Spikes/Burst', 'bursting',
#        'iso_dist', 'L_ratio', 'ISI_min', 'ISI_max', 'ISI_mean', 'ISI_median',
#        'ISI_cv', 'ISI_std', 'sparsity', 'selectivity', 'information',
#        'coherence', 'speed_score', 'hd_score', 'grid_score',
#        'border_score_top', 'border_score_bottom', 'border_score_left',
#        'border_score_right', 'field_sizes', 'Field_1', 'Field_2', 'Field_3',
#        'Field_4', 'Field_5', 'Field_6', 'group', 'Field_7', 'Field_8',
#        'date_time', 'ses_ct'],
#       dtype='object')

# %%
df_neurofunc['ses_ct'].unique()
# Out:
# array([2, 3, 1, 4, 5, 6, 7], dtype=object)

# %%
# print Session where date_time is NaT
print(df_neurofunc[df_neurofunc['date_time'].isna()]['Session'].unique())
print(len(df_neurofunc[df_neurofunc['date_time'].isna()]['Session'].unique()), len(df_neurofunc['Session'].unique()))
# Out:
# []
# 0 1345

# %%
# df_neurofunc.to_excel('object_complete.xlsx')

# %%
# Need to match neurofunc and remapping
import re
from scripts.batch_map.LEC_naming import LEC_naming_format, extract_name_lec

def _check_single_format(filename, fformat, fxn):
    if re.match(str(fformat), str(filename)) is not None:
        return list(fxn(filename))

# For neurofunc need to add extract, date, depth, name, stim 
# iterate thru rows of df_neurofunc and extract from signature
for i, row in df_neurofunc.iterrows():
    # extract
    fname = row['Session']
    
    if 'CAGE' in fname:
        # drop row
        df_neurofunc.drop(i, inplace=True)
    else:
        group, name = extract_name_lec(fname)
        formats = LEC_naming_format[group][name]['object']

        for fformat in list(formats.keys()):
            checked = _check_single_format(fname, fformat, formats[fformat])
            if checked is not None:
                break

        stim, depth, name, date = checked
        
        df_neurofunc.at[i, 'date'] = date
        df_neurofunc.at[i, 'depth'] = str(int(depth))
        df_neurofunc.at[i, 'name'] = name
        df_neurofunc.at[i, 'stim'] = stim

# %%
# neurofunc_row_identifiers = ['name','Tetrode', 'Cell ID', 'date', 'depth', 'stim']
# remapping_row_identifiers = ['name','tetrode', 'unit_id', 'date', 'depth','object_location']

# df_remapping_to_merge = df_remapping[df_remapping['score'] == 'whole']

# for row in neurofunc_row_identifiers:
#     df_neurofunc[row] = df_neurofunc[row].astype(str)
# for row in remapping_row_identifiers:
#     df_remapping_to_merge[row] = df_remapping_to_merge[row].astype(str)

# matched_df = None
# for i, row in df_remapping_to_merge.iterrows():
#     # find row in df_neurofunc that mathces using identifiers
#     for j, row2 in df_neurofunc.iterrows():
#         matched = True
#         for k in range(len(neurofunc_row_identifiers)):
#             print('pair ' + str(neurofunc_row_identifiers[k]))
#             print('new2')
#             print(row2[neurofunc_row_identifiers[k]])
#             print('new')
#             print(row[remapping_row_identifiers[k]])
            
#             if row2[neurofunc_row_identifiers[k]] != row[remapping_row_identifiers[k]]:
#                 matched = False

#         # if row2[neurofunc_row_identifiers] == row[remapping_row_identifiers]:
#         if matched == True:
#             if matched_df is None:
#                 row = pd.concat([row, row2], axis=0)
#                 matched_df = row
#             else:
#                 row = pd.concat([row, row2], axis=0)
#                 matched_df = pd.concat([matched_df, row], axis=1)

# %%
import pandas as pd

# Define the common columns
neurofunc_row_identifiers = ['name', 'Tetrode', 'Cell ID', 'date', 'depth', 'stim']
remapping_row_identifiers = ['name', 'tetrode', 'unit_id', 'date', 'depth', 'object_location']

for row in neurofunc_row_identifiers:
    df_neurofunc[row] = df_neurofunc[row].astype(str)
for row in remapping_row_identifiers:
    df_remapping[row] = df_remapping[row].astype(str)
df_neurofunc['Session'] = df_neurofunc['Session'].astype(str)
df_remapping['signature'] = df_remapping['signature'].astype(str)

# %%
# Create an empty list to store the merged rows
merged_rows = []

# Iterate through each row in df_remapping
for remapping_row in df_remapping.itertuples(index=False):
    # Extract the identifiers from the remapping row
    remapping_identifiers = [getattr(remapping_row, col) for col in remapping_row_identifiers]

    # Find the matching row in df_neurofunc based on the identifiers
    matching_row = df_neurofunc.loc[
        (df_neurofunc[neurofunc_row_identifiers] == remapping_identifiers).all(axis=1)
    ]

    if len(matching_row) > 1:
        # # pick row where neurofunc at column called 'Session' is the same as remapping at 'signature'
        # neurofunc_row_identifiers = ['Session','name', 'Tetrode', 'Cell ID', 'date', 'depth', 'stim']
        # remapping_row_identifiers = ['signature','name', 'tetrode', 'unit_id', 'date', 'depth', 'object_location']
        # remapping_identifiers = [getattr(remapping_row, col) for col in remapping_row_identifiers]

        # # Find the matching row in df_neurofunc based on the identifiers
        # matching_row = df_neurofunc.loc[
        #     (df_neurofunc[neurofunc_row_identifiers] == remapping_identifiers).all(axis=1)
        # ]
        # print('new')
        # print(len(matching_row))
        remapping_row_ses_ct = int(remapping_row[7].split('_')[-1])
        # print(matching_row['ses_ct'] == remapping_row_ses_ct, matching_row['ses_ct'], remapping_row_ses_ct)
        matching_row = matching_row[matching_row['ses_ct'] == remapping_row_ses_ct]


    # Check if a matching row was found
    if len(matching_row) == 0:
        print("Found {} matching rows for {}".format(len(matching_row), remapping_identifiers))
        print(matching_row['Session'], getattr(remapping_row, 'signature'))
        # stop()
    elif len(matching_row) > 1:
        # check all rows are matching on spatial info score 
        prev = None
        for i, row in matching_row.iterrows():
            if prev is None:
                prev = row['spike_count']
            else:
                if prev != row['spike_count']:
                    print('multiple matches')
                    print(matching_row)
                    # stop()
        
    # Join the matching rows
    # merged_row = pd.concat([matching_row, pd.DataFrame([remapping_row], columns=df_remapping.columns)], axis=1)
    merged_rows.append(matching_row)

# Create the merged dataframe
merged_df = pd.concat(merged_rows, ignore_index=True)

# Print the merged dataframe
# print(merged_df)
# Out:
# Found 0 matching rows for ['ANT-135a-7', '7', '2', '20180611', '3125', '270']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180611-ROUND-3125-270
# Found 0 matching rows for ['ANT-135a-7', '7', '2', '20180611', '3125', '270']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180611-ROUND-3125-270
# Found 0 matching rows for ['ANT-135a-7', '7', '2', '20180611', '3125', '270']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180611-ROUND-3125-270
# Found 0 matching rows for ['ANT-135a-7', '7', '2', '20180611', '3125', '270']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180611-ROUND-3125-270
# Found 0 matching rows for ['ANT-135a-7', '7', '2', '20180611', '3125', '270']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180611-ROUND-3125-270
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', '180']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-180
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', '180']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-180
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', '180']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-180
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', '180']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-180
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', '180']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-180
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', '180']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-180
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', '180']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-180
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', '180']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-180
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', 'NO']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-NO-2
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', 'NO']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-NO-2
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', 'NO']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-NO-2
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', 'NO']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-NO-2
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', 'NO']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-NO-2
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', 'NO']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-NO-2
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', 'NO']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-NO-2
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', 'NO']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-NO-2
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', '180']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-180-2
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', '180']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-180-2
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', '180']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-180-2
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', '180']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-180-2
# Found 0 matching rows for ['ANT-135a-7', '6', '5', '20180620', '3300', '180']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180620-ROUND-3300-180-2
# Found 0 matching rows for ['ANT-135a-7', '7', '1', '20180621', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180621-ROUND-3300-90
# Found 0 matching rows for ['ANT-135a-7', '7', '1', '20180621', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180621-ROUND-3300-90
# Found 0 matching rows for ['ANT-135a-7', '7', '1', '20180621', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180621-ROUND-3300-90
# Found 0 matching rows for ['ANT-135a-7', '7', '1', '20180621', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180621-ROUND-3300-90
# Found 0 matching rows for ['ANT-135a-7', '7', '1', '20180621', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180621-ROUND-3300-90
# Found 0 matching rows for ['ANT-135a-7', '7', '1', '20180625', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180625-ROUND-3300-90-2
# Found 0 matching rows for ['ANT-135a-7', '7', '1', '20180625', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180625-ROUND-3300-90-2
# Found 0 matching rows for ['ANT-135a-7', '7', '1', '20180625', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180625-ROUND-3300-90-2
# Found 0 matching rows for ['ANT-135a-7', '7', '1', '20180625', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180625-ROUND-3300-90-2
# Found 0 matching rows for ['ANT-135a-7', '7', '1', '20180625', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-135a-7_20180625-ROUND-3300-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180706', '3350', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-180-2
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180706', '3350', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-180-2
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180706', '3350', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-180-2
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180706', '3350', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-180-2
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180706', '3350', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-180-2
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180706', '3350', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-180-2
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180706', '3350', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-180-2
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180706', '3350', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-180-2
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180706', '3350', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180706', '3350', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180706', '3350', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180706', '3350', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180706', '3350', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180706', '3350', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-NO-2
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180706', '3350', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-NO-2
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180706', '3350', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-NO-2
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180706', '3350', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-NO-2
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180706', '3350', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-NO-2
# Found 0 matching rows for ['ANT-140-4', '6', '2', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '6', '2', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '6', '2', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '6', '2', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '6', '2', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '6', '2', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '6', '2', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '6', '2', '20180706', '3350', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-270
# Found 0 matching rows for ['ANT-140-4', '6', '2', '20180706', '3350', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '2', '20180706', '3350', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '2', '20180706', '3350', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '2', '20180706', '3350', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '2', '20180706', '3350', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180706-ROUND-3350-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180705', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180705', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180705', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180705', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180705', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180705', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180705', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180705', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180705', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180705', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180705', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180705', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180705', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180705', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180705', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180705', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180705', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180705', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180705', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180705', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180705', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180705', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180705', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180705', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180705-ROUND-3300-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180703', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180703-ROUND-3300-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180703', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180703-ROUND-3300-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180703', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180703-ROUND-3300-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180703', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180703-ROUND-3300-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180703', '3300', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180703-ROUND-3300-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180703', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180703-ROUND-3300-270-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180703', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180703-ROUND-3300-270-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180703', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180703-ROUND-3300-270-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180703', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180703-ROUND-3300-270-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180703', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180703-ROUND-3300-270-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180703', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180703-ROUND-3300-270-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180703', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180703-ROUND-3300-270-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180703', '3300', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180703-ROUND-3300-270-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-270
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180702', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180702', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180702', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180702', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180702', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180702', '3250', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180702-ROUND-3250-NO-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180629', '3250', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180629-ROUND-3250-90
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180629', '3250', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180629-ROUND-3250-90
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180629', '3250', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180629-ROUND-3250-90
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180629', '3250', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180629-ROUND-3250-90
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180629', '3250', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180629-ROUND-3250-90
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180629', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180629-ROUND-3250-270-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180629', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180629-ROUND-3250-270-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180629', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180629-ROUND-3250-270-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180629', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180629-ROUND-3250-270-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180629', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180629-ROUND-3250-270-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180629', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180629-ROUND-3250-270-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180629', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180629-ROUND-3250-270-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180629', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180629-ROUND-3250-270-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180629', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180629-ROUND-3250-270-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180629', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180629-ROUND-3250-270-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180629', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180629-ROUND-3250-270-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180629', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180629-ROUND-3250-270-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180629', '3250', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180629-ROUND-3250-270-2
# Found 0 matching rows for ['ANT-140-4', '3', '6', '20180628', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-90
# Found 0 matching rows for ['ANT-140-4', '3', '6', '20180628', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-90
# Found 0 matching rows for ['ANT-140-4', '3', '6', '20180628', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-90
# Found 0 matching rows for ['ANT-140-4', '3', '6', '20180628', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-90
# Found 0 matching rows for ['ANT-140-4', '3', '6', '20180628', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-90
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-180-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-180-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-180-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-180-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-180-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-180-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-180-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-180-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-270-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-270-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-270-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-270-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-270-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-270-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-270-2
# Found 0 matching rows for ['ANT-140-4', '3', '8', '20180628', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-270-2
# Found 0 matching rows for ['ANT-140-4', '4', '7', '20180628', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-90
# Found 0 matching rows for ['ANT-140-4', '4', '7', '20180628', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-90
# Found 0 matching rows for ['ANT-140-4', '4', '7', '20180628', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-90
# Found 0 matching rows for ['ANT-140-4', '4', '7', '20180628', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-90
# Found 0 matching rows for ['ANT-140-4', '4', '7', '20180628', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-90
# Found 0 matching rows for ['ANT-140-4', '4', '7', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO
# Found 0 matching rows for ['ANT-140-4', '4', '7', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO
# Found 0 matching rows for ['ANT-140-4', '4', '7', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO
# Found 0 matching rows for ['ANT-140-4', '4', '7', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO
# Found 0 matching rows for ['ANT-140-4', '4', '7', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO
# Found 0 matching rows for ['ANT-140-4', '4', '7', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO-2
# Found 0 matching rows for ['ANT-140-4', '4', '7', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO-2
# Found 0 matching rows for ['ANT-140-4', '4', '7', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO-2
# Found 0 matching rows for ['ANT-140-4', '4', '7', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO-2
# Found 0 matching rows for ['ANT-140-4', '4', '7', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO-2
# Found 0 matching rows for ['ANT-140-4', '4', '7', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO-2
# Found 0 matching rows for ['ANT-140-4', '4', '7', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO-2
# Found 0 matching rows for ['ANT-140-4', '4', '7', '20180628', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-NO-2
# Found 0 matching rows for ['ANT-140-4', '7', '6', '20180628', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-90
# Found 0 matching rows for ['ANT-140-4', '7', '6', '20180628', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-90
# Found 0 matching rows for ['ANT-140-4', '7', '6', '20180628', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-90
# Found 0 matching rows for ['ANT-140-4', '7', '6', '20180628', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-90
# Found 0 matching rows for ['ANT-140-4', '7', '6', '20180628', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-90
# Found 0 matching rows for ['ANT-140-4', '7', '6', '20180628', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-270-2
# Found 0 matching rows for ['ANT-140-4', '7', '6', '20180628', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-270-2
# Found 0 matching rows for ['ANT-140-4', '7', '6', '20180628', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-270-2
# Found 0 matching rows for ['ANT-140-4', '7', '6', '20180628', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-270-2
# Found 0 matching rows for ['ANT-140-4', '7', '6', '20180628', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180628-ROUND-3200-270-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180627', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180627', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180627', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180627', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180627', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180627', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180627', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180627', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180627', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-NO
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180627', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-NO
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180627', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-NO
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180627', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-NO
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180627', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-NO
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180627', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-NO
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180627', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-NO
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180627', '3200', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-NO
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180627', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-270
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180627', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-270
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180627', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-270
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180627', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-270
# Found 0 matching rows for ['ANT-140-4', '1', '5', '20180627', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-180
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180627', '3200', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180627-ROUND-3200-90-2
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180625', '3150', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-180
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180625', '3150', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-180
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180625', '3150', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-180
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180625', '3150', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-180
# Found 0 matching rows for ['ANT-140-4', '1', '1', '20180625', '3150', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-180
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180625', '3150', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-180
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180625', '3150', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-180
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180625', '3150', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-180
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180625', '3150', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-180
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180625', '3150', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-180
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180625', '3150', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180625', '3150', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180625', '3150', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180625', '3150', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180625', '3150', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180625', '3150', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180625', '3150', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180625', '3150', '90']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-90-2
# Found 0 matching rows for ['ANT-140-4', '6', '5', '20180625', '3150', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-180
# Found 0 matching rows for ['ANT-140-4', '6', '5', '20180625', '3150', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-180
# Found 0 matching rows for ['ANT-140-4', '6', '5', '20180625', '3150', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-180
# Found 0 matching rows for ['ANT-140-4', '6', '5', '20180625', '3150', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-180
# Found 0 matching rows for ['ANT-140-4', '6', '5', '20180625', '3150', '180']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-180
# Found 0 matching rows for ['ANT-140-4', '6', '5', '20180625', '3150', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-270
# Found 0 matching rows for ['ANT-140-4', '6', '5', '20180625', '3150', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-270
# Found 0 matching rows for ['ANT-140-4', '6', '5', '20180625', '3150', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-270
# Found 0 matching rows for ['ANT-140-4', '6', '5', '20180625', '3150', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-270
# Found 0 matching rows for ['ANT-140-4', '6', '5', '20180625', '3150', '270']
# Series([], Name: Session, dtype: object) ANT-140-4_20180625-ROUND-3150-270
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180622', '3150', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180622-ROUND-3150-NO
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180622', '3150', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180622-ROUND-3150-NO
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180622', '3150', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180622-ROUND-3150-NO
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180622', '3150', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180622-ROUND-3150-NO
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180622', '3150', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180622-ROUND-3150-NO
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180622', '3150', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180622-ROUND-3150-NO-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180622', '3150', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180622-ROUND-3150-NO-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180622', '3150', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180622-ROUND-3150-NO-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180622', '3150', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180622-ROUND-3150-NO-2
# Found 0 matching rows for ['ANT-140-4', '6', '1', '20180622', '3150', 'NO']
# Series([], Name: Session, dtype: object) ANT-140-4_20180622-ROUND-3150-NO-2
# ...
#
#        Field_6  group  Field_7  Field_8           date_time  ses_ct      date  \
# 18940      NaN     B6      NaN      NaN 2017-02-02 13:05:26       1  20170202
# 20193      NaN     B6      NaN      NaN 2017-02-02 13:05:26       1  20170202
#
#        depth   name  stim
# 18940   3450  B6-1M    NO
# 20193   3450  B6-1M    NO
#
# [2 rows x 44 columns]
# multiple matches
#        Unnamed: 0                 Session Tetrode Cell ID  spike_width  \
# 18940        42.0  B6-1M_20170202-NO-3450       4       4     0.000417
# 20193        47.0  B6-1M_20170202-NO-3450       4       4     0.000521
#
#        spike_count  firing_rate  Avg. Spikes/Burst  bursting  iso_dist  ...  \
# 18940         1719     2.860233           6.058824  4.945455  4.364757  ...
# 20193         2107     3.505824           2.206897  2.847324  4.535450  ...
#
#        Field_6  group  Field_7  Field_8           date_time  ses_ct      date  \
# 18940      NaN     B6      NaN      NaN 2017-02-02 13:05:26       1  20170202
# 20193      NaN     B6      NaN      NaN 2017-02-02 13:05:26       1  20170202
#
#        depth   name  stim
# 18940   3450  B6-1M    NO
# 20193   3450  B6-1M    NO
#
# [2 rows x 44 columns]
# multiple matches
#        Unnamed: 0                 Session Tetrode Cell ID  spike_width  \
# 18940        42.0  B6-1M_20170202-NO-3450       4       4     0.000417
# 20193        47.0  B6-1M_20170202-NO-3450       4       4     0.000521
#
#        spike_count  firing_rate  Avg. Spikes/Burst  bursting  iso_dist  ...  \
# 18940         1719     2.860233           6.058824  4.945455  4.364757  ...
# 20193         2107     3.505824           2.206897  2.847324  4.535450  ...
#
#        Field_6  group  Field_7  Field_8           date_time  ses_ct      date  \
# 18940      NaN     B6      NaN      NaN 2017-02-02 13:05:26       1  20170202
# 20193      NaN     B6      NaN      NaN 2017-02-02 13:05:26       1  20170202
#
#        depth   name  stim
# 18940   3450  B6-1M    NO
# 20193   3450  B6-1M    NO
#
# [2 rows x 44 columns]
# multiple matches
#        Unnamed: 0                 Session Tetrode Cell ID  spike_width  \
# 18940        42.0  B6-1M_20170202-NO-3450       4       4     0.000417
# 20193        47.0  B6-1M_20170202-NO-3450       4       4     0.000521
#
#        spike_count  firing_rate  Avg. Spikes/Burst  bursting  iso_dist  ...  \
# 18940         1719     2.860233           6.058824  4.945455  4.364757  ...
# 20193         2107     3.505824           2.206897  2.847324  4.535450  ...
#
#        Field_6  group  Field_7  Field_8           date_time  ses_ct      date  \
# 18940      NaN     B6      NaN      NaN 2017-02-02 13:05:26       1  20170202
# 20193      NaN     B6      NaN      NaN 2017-02-02 13:05:26       1  20170202
#
#        depth   name  stim
# 18940   3450  B6-1M    NO
# 20193   3450  B6-1M    NO
#
# [2 rows x 44 columns]
# multiple matches
#        Unnamed: 0                 Session Tetrode Cell ID  spike_width  \
# 18940        42.0  B6-1M_20170202-NO-3450       4       4     0.000417
# 20193        47.0  B6-1M_20170202-NO-3450       4       4     0.000521
#
#        spike_count  firing_rate  Avg. Spikes/Burst  bursting  iso_dist  ...  \
# 18940         1719     2.860233           6.058824  4.945455  4.364757  ...
# 20193         2107     3.505824           2.206897  2.847324  4.535450  ...
#
#        Field_6  group  Field_7  Field_8           date_time  ses_ct      date  \
# 18940      NaN     B6      NaN      NaN 2017-02-02 13:05:26       1  20170202
# 20193      NaN     B6      NaN      NaN 2017-02-02 13:05:26       1  20170202
#
#        depth   name  stim
# 18940   3450  B6-1M    NO
# 20193   3450  B6-1M    NO
#
# [2 rows x 44 columns]
# multiple matches
#        Unnamed: 0                 Session Tetrode Cell ID  spike_width  \
# 18924        26.0  B6-1M_20170202-90-3450       4       4     0.000438
# 20177        31.0  B6-1M_20170202-90-3450       4       4     0.000479
#
#        spike_count  firing_rate  Avg. Spikes/Burst  bursting  iso_dist  ...  \
# 18924         4392     7.307820           3.956044  7.615063  7.368813  ...
# 20177         1263     2.101498           2.074074  2.188006  3.321946  ...
#
#        Field_6  group  Field_7  Field_8           date_time  ses_ct      date  \
# 18924      NaN     B6      NaN      NaN 2017-02-02 13:17:21       2  20170202
# 20177      NaN     B6      NaN      NaN 2017-02-02 13:17:21       2  20170202
#
#        depth   name  stim
# 18924   3450  B6-1M    90
# 20177   3450  B6-1M    90
#
# [2 rows x 44 columns]
# multiple matches
#        Unnamed: 0                 Session Tetrode Cell ID  spike_width  \
# 18924        26.0  B6-1M_20170202-90-3450       4       4     0.000438
# 20177        31.0  B6-1M_20170202-90-3450       4       4     0.000479
#
#        spike_count  firing_rate  Avg. Spikes/Burst  bursting  iso_dist  ...  \
# 18924         4392     7.307820           3.956044  7.615063  7.368813  ...
# 20177         1263     2.101498           2.074074  2.188006  3.321946  ...
#
#        Field_6  group  Field_7  Field_8           date_time  ses_ct      date  \
# 18924      NaN     B6      NaN      NaN 2017-02-02 13:17:21       2  20170202
# 20177      NaN     B6      NaN      NaN 2017-02-02 13:17:21       2  20170202
#
#        depth   name  stim
# 18924   3450  B6-1M    90
# 20177   3450  B6-1M    90
#
# [2 rows x 44 columns]
# multiple matches
#        Unnamed: 0                 Session Tetrode Cell ID  spike_width  \
# 18924        26.0  B6-1M_20170202-90-3450       4       4     0.000438
# 20177        31.0  B6-1M_20170202-90-3450       4       4     0.000479
#
#        spike_count  firing_rate  Avg. Spikes/Burst  bursting  iso_dist  ...  \
# 18924         4392     7.307820           3.956044  7.615063  7.368813  ...
# 20177         1263     2.101498           2.074074  2.188006  3.321946  ...
#
#        Field_6  group  Field_7  Field_8           date_time  ses_ct      date  \
# 18924      NaN     B6      NaN      NaN 2017-02-02 13:17:21       2  20170202
# 20177      NaN     B6      NaN      NaN 2017-02-02 13:17:21       2  20170202
#
#        depth   name  stim
# 18924   3450  B6-1M    90
# 20177   3450  B6-1M    90
#
# [2 rows x 44 columns]
# multiple matches
#        Unnamed: 0                 Session Tetrode Cell ID  spike_width  \
# 18924        26.0  B6-1M_20170202-90-3450       4       4     0.000438
# 20177        31.0  B6-1M_20170202-90-3450       4       4     0.000479
#
#        spike_count  firing_rate  Avg. Spikes/Burst  bursting  iso_dist  ...  \
# 18924         4392     7.307820           3.956044  7.615063  7.368813  ...
# 20177         1263     2.101498           2.074074  2.188006  3.321946  ...
#
#        Field_6  group  Field_7  Field_8           date_time  ses_ct      date  \
# 18924      NaN     B6      NaN      NaN 2017-02-02 13:17:21       2  20170202
# 20177      NaN     B6      NaN      NaN 2017-02-02 13:17:21       2  20170202
#
#        depth   name  stim
# 18924   3450  B6-1M    90
# 20177   3450  B6-1M    90
#
# [2 rows x 44 columns]
# multiple matches
#        Unnamed: 0                 Session Tetrode Cell ID  spike_width  \
# 18924        26.0  B6-1M_20170202-90-3450       4       4     0.000438
# 20177        31.0  B6-1M_20170202-90-3450       4       4     0.000479
#
#        spike_count  firing_rate  Avg. Spikes/Burst  bursting  iso_dist  ...  \
# 18924         4392     7.307820           3.956044  7.615063  7.368813  ...
# 20177         1263     2.101498           2.074074  2.188006  3.321946  ...
#
#        Field_6  group  Field_7  Field_8           date_time  ses_ct      date  \
# 18924      NaN     B6      NaN      NaN 2017-02-02 13:17:21       2  20170202
# 20177      NaN     B6      NaN      NaN 2017-02-02 13:17:21       2  20170202
#
#        depth   name  stim
# 18924   3450  B6-1M    90
# 20177   3450  B6-1M    90
#
# [2 rows x 44 columns]
# multiple matches
#        Unnamed: 0                  Session Tetrode Cell ID  spike_width  \
# 18911        13.0  B6-1M_20170202-180-3450       4       4     0.000500
# 20161        15.0  B6-1M_20170202-180-3450       4       4     0.000521
#
#        spike_count  firing_rate  Avg. Spikes/Burst   bursting  iso_dist  ...  \
# 18911         7241    12.048253           2.645441  11.320446  9.171097  ...
# 20161         2574     4.282862           2.159574   3.813387  4.112392  ...
#
#        Field_6  group  Field_7  Field_8           date_time  ses_ct      date  \
# 18911      NaN     B6      NaN      NaN 2017-02-02 13:40:36       3  20170202
# 20161      NaN     B6      NaN      NaN 2017-02-02 13:40:36       3  20170202
#
#        depth   name  stim
# 18911   3450  B6-1M   180
# 20161   3450  B6-1M   180
#
# [2 rows x 44 columns]
# multiple matches
#        Unnamed: 0                  Session Tetrode Cell ID  spike_width  \
# 18911        13.0  B6-1M_20170202-180-3450       4       4     0.000500
# 20161        15.0  B6-1M_20170202-180-3450       4       4     0.000521
#
#        spike_count  firing_rate  Avg. Spikes/Burst   bursting  iso_dist  ...  \
# 18911         7241    12.048253           2.645441  11.320446  9.171097  ...
# 20161         2574     4.282862           2.159574   3.813387  4.112392  ...
#
#        Field_6  group  Field_7  Field_8           date_time  ses_ct      date  \
# 18911      NaN     B6      NaN      NaN 2017-02-02 13:40:36       3  20170202
# 20161      NaN     B6      NaN      NaN 2017-02-02 13:40:36       3  20170202
#
#        depth   name  stim
# 18911   3450  B6-1M   180
# 20161   3450  B6-1M   180
#
# [2 rows x 44 columns]
# multiple matches
#        Unnamed: 0                  Session Tetrode Cell ID  spike_width  \
# 18911        13.0  B6-1M_20170202-180-3450       4       4     0.000500
# 20161        15.0  B6-1M_20170202-180-3450       4       4     0.000521
#
#        spike_count  firing_rate  Avg. Spikes/Burst   bursting  iso_dist  ...  \
# 18911         7241    12.048253           2.645441  11.320446  9.171097  ...
# 20161         2574     4.282862           2.159574   3.813387  4.112392  ...
#
#        Field_6  group  Field_7  Field_8           date_time  ses_ct      date  \
# 18911      NaN     B6      NaN      NaN 2017-02-02 13:40:36       3  20170202
# 20161      NaN     B6      NaN      NaN 2017-02-02 13:40:36       3  20170202
#
#        depth   name  stim
# 18911   3450  B6-1M   180
# 20161   3450  B6-1M   180
#
# [2 rows x 44 columns]
# multiple matches
#        Unnamed: 0                  Session Tetrode Cell ID  spike_width  \
# 18911        13.0  B6-1M_20170202-180-3450       4       4     0.000500
# 20161        15.0  B6-1M_20170202-180-3450       4       4     0.000521
#
#        spike_count  firing_rate  Avg. Spikes/Burst   bursting  iso_dist  ...  \
# 18911         7241    12.048253           2.645441  11.320446  9.171097  ...
# 20161         2574     4.282862           2.159574   3.813387  4.112392  ...
#
#        Field_6  group  Field_7  Field_8           date_time  ses_ct      date  \
# 18911      NaN     B6      NaN      NaN 2017-02-02 13:40:36       3  20170202
# 20161      NaN     B6      NaN      NaN 2017-02-02 13:40:36       3  20170202
#
#        depth   name  stim
# 18911   3450  B6-1M   180
# 20161   3450  B6-1M   180
#
# [2 rows x 44 columns]
# multiple matches
#        Unnamed: 0                  Session Tetrode Cell ID  spike_width  \
# 18911        13.0  B6-1M_20170202-180-3450       4       4     0.000500
# 20161        15.0  B6-1M_20170202-180-3450       4       4     0.000521
#
#        spike_count  firing_rate  Avg. Spikes/Burst   bursting  iso_dist  ...  \
# 18911         7241    12.048253           2.645441  11.320446  9.171097  ...
# 20161         2574     4.282862           2.159574   3.813387  4.112392  ...
#
#        Field_6  group  Field_7  Field_8           date_time  ses_ct      date  \
# 18911      NaN     B6      NaN      NaN 2017-02-02 13:40:36       3  20170202
# 20161      NaN     B6      NaN      NaN 2017-02-02 13:40:36       3  20170202
#
#        depth   name  stim
# 18911   3450  B6-1M   180
# 20161   3450  B6-1M   180
#
# [2 rows x 44 columns]
# Found 0 matching rows for ['B6-LEC2', '4', '1', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '1', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '1', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '1', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '1', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '1', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '1', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '1', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '2', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '2', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '2', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '2', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '2', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '2', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '2', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '2', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '3', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '3', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '3', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '3', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '3', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '4', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '4', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '4', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '4', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '4', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '4', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '4', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270
# Found 0 matching rows for ['B6-LEC2', '4', '4', '20160122', '3475', '270']
# Series([], Name: Session, dtype: object) B6-LEC2_20160122-270

# %%
remapping_identifiers = [getattr(remapping_row, col) for col in remapping_row_identifiers]

    # Find the matching row in df_neurofunc based on the identifiers
matching_row = df_neurofunc.loc[
        (df_neurofunc[neurofunc_row_identifiers] == remapping_identifiers).all(axis=1)
    ]

# %%
remapping_identifiers
# Out:
# ['B6-LEC2', '4', '7', '20151216', '3475', '90']

# %%
df_neurofunc['ses_ct'].unique()
# Out:
# array([2, 3, 1, 4, 5, 6, 7], dtype=object)

# %%
df_remapping['session_id'].unique()
# Out:
# array(['session_2', 'session_3', 'session_1', 'session_4', 'session_5',
#        'session_6', 'session_7'], dtype=object)

# %%
matching_row
# Out:
#        Unnamed: 0                  Session Tetrode Cell ID  spike_width  \
# 26443        26.0    B6-LEC2_20151216-0-90       4       7     0.000292
# 26470        53.0  B6-LEC2_20151216-0-90_2       4       7     0.000292
#
#        spike_count  firing_rate  Avg. Spikes/Burst  bursting  iso_dist  ...  \
# 26443          381     0.317236           1.999025  0.000000  2.487047  ...
# 26470          385     0.320566           2.000000  0.260417  2.506928  ...
#
#        Field_6  group  Field_7  Field_8           date_time  ses_ct      date  \
# 26443      NaN     B6      NaN      NaN 2015-12-16 11:13:08       1  20151216
# 26470      NaN     B6      NaN      NaN 2015-12-16 11:13:08       2  20151216
#
#        depth     name  stim
# 26443   3475  B6-LEC2    90
# 26470   3475  B6-LEC2    90
#
# [2 rows x 44 columns]

# %%
remapping_row[7]
# Out:
# 'session_2'

# %%
print(df_neurofunc.shape, df_remapping.shape, merged_df.shape)
# Out:
# (26533, 44) (120475, 46) (119414, 44)

# %%
merged_df
# Out:
#         Unnamed: 0                       Session Tetrode Cell ID  spike_width  \
# 0             46.0  ANT-119a-6_20170605-3050-270       1       1     0.000083
# 1             46.0  ANT-119a-6_20170605-3050-270       1       1     0.000083
# 2             46.0  ANT-119a-6_20170605-3050-270       1       1     0.000083
# 3             46.0  ANT-119a-6_20170605-3050-270       1       1     0.000083
# 4             46.0  ANT-119a-6_20170605-3050-270       1       1     0.000083
# ...            ...                           ...     ...     ...          ...
# 119409        53.0       B6-LEC2_20151216-0-90_2       4       7     0.000292
# 119410        53.0       B6-LEC2_20151216-0-90_2       4       7     0.000292
# 119411        53.0       B6-LEC2_20151216-0-90_2       4       7     0.000292
# 119412        53.0       B6-LEC2_20151216-0-90_2       4       7     0.000292
# 119413        53.0       B6-LEC2_20151216-0-90_2       4       7     0.000292
#
#         spike_count  firing_rate  Avg. Spikes/Burst   bursting   iso_dist  \
# 0              2626     4.369384           2.471698  14.735867  18.513673
# 1              2626     4.369384           2.471698  14.735867  18.513673
# 2              2626     4.369384           2.471698  14.735867  18.513673
# 3              2626     4.369384           2.471698  14.735867  18.513673
# 4              2626     4.369384           2.471698  14.735867  18.513673
# ...             ...          ...                ...        ...        ...
# 119409          385     0.320566           2.000000   0.260417   2.506928
# 119410          385     0.320566           2.000000   0.260417   2.506928
# 119411          385     0.320566           2.000000   0.260417   2.506928
# 119412          385     0.320566           2.000000   0.260417   2.506928
# 119413          385     0.320566           2.000000   0.260417   2.506928
#
#         ...  Field_6  group  Field_7  Field_8           date_time  ses_ct  \
# 0       ...      NaN    ANT      NaN      NaN 2017-06-05 14:28:49       2
# 1       ...      NaN    ANT      NaN      NaN 2017-06-05 14:28:49       2
# 2       ...      NaN    ANT      NaN      NaN 2017-06-05 14:28:49       2
# 3       ...      NaN    ANT      NaN      NaN 2017-06-05 14:28:49       2
# 4       ...      NaN    ANT      NaN      NaN 2017-06-05 14:28:49       2
# ...     ...      ...    ...      ...      ...                 ...     ...
# 119409  ...      NaN     B6      NaN      NaN 2015-12-16 11:13:08       2
# 119410  ...      NaN     B6      NaN      NaN 2015-12-16 11:13:08       2
# 119411  ...      NaN     B6      NaN      NaN 2015-12-16 11:13:08       2
# 119412  ...      NaN     B6      NaN      NaN 2015-12-16 11:13:08       2
# 119413  ...      NaN     B6      NaN      NaN 2015-12-16 11:13:08       2
#
#                      date  depth        name  stim
# 0       20170605-3050-270   3050  ANT-119a-6   270
# 1       20170605-3050-270   3050  ANT-119a-6   270
# 2       20170605-3050-270   3050  ANT-119a-6   270
# 3       20170605-3050-270   3050  ANT-119a-6   270
# 4       20170605-3050-270   3050  ANT-119a-6   270
# ...                   ...    ...         ...   ...
# 119409           20151216   3475     B6-LEC2    90
# 119410           20151216   3475     B6-LEC2    90
# 119411           20151216   3475     B6-LEC2    90
# 119412           20151216   3475     B6-LEC2    90
# 119413           20151216   3475     B6-LEC2    90
#
# [119414 rows x 44 columns]
