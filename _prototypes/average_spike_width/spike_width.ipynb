# %%
# Outside imports
import os, sys
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Set necessary paths / make project path = ...../neuroscikit/
avg_spike_width_path = os.getcwd()
prototype_path = os.path.abspath(os.path.join(avg_spike_width_path, os.pardir))
project_path = os.path.abspath(os.path.join(prototype_path, os.pardir))
lab_path = os.path.abspath(os.path.join(project_path, os.pardir))
sys.path.append(project_path)
os.chdir(project_path)
print(project_path)

# Internal imports
from _prototypes.average_spike_width.src.spike_width import extract_average_spike_widths
from _prototypes.average_spike_width.src.settings import settings_dict

# Read write modules
from x_io.rw.axona.batch_read import make_study
# Out:
# k:\ke

# %%
data_dir = lab_path + r'\neuroscikit_test_data\axona'
output_dir = lab_path + r'\neuroscikit\_prototypes\average_spike_width\output'
print(data_dir)
print(output_dir)
# Out:
# k:\ke\dev\neuroscikit_test_data\axona
# k:\ke\dev\neuroscikit\_prototypes\average_spike_width\output

# %%
study = make_study([data_dir], settings_dict)
study.make_animals()
# Out:
# k:\ke\dev\neuroscikit\library\study_space.py:44: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   dir_names = np.array([x[1] for x in os.walk('library')])[0]
# Animal ID set
# Animal ID set
# Session data added, spikes sorted by cell
# Session data added, spikes sorted by cell

# %%
output_dict = extract_average_spike_widths(study)

# %%
pd.DataFrame(output_dict)
# Out:
#      animal_id      session_signature  unit_id  spike_width  firing_rate
# 0   axona_tet1  20140815-behavior2-90        1         0.46    23.289462
# 1   axona_tet1  20140815-behavior2-90        2         0.42     1.108662
# 2   axona_tet1  20140815-behavior2-90        3         0.44     0.251539
# 3   axona_tet1  20140815-behavior2-90        4         0.42     1.469883
# 4   axona_tet1  20140815-behavior2-90        5         0.44    21.760173
# 5   axona_tet1  20140815-behavior2-90        6         0.46     4.204633
# 6   axona_tet1  20140815-behavior2-90        7         0.46     6.126191
# 7   axona_tet1  20140815-behavior2-90        8         0.44    11.204727
# 8   axona_tet1  20140815-behavior2-90        9         0.44     1.922465
# 9   axona_tet1  20140815-behavior2-90       10         0.10     2.404056
# 10  axona_tet1  20140815-behavior2-90       11         0.40     8.124101
# 11  axona_tet1  20140815-behavior2-90       12         0.42     0.166500
# ...

# %%
pd.DataFrame(output_dict).to_csv(output_dir + r'\spike_widths.csv')
